# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %%
from prophet import Prophet

# %%
data = pd.read_csv('../data/master.csv')
data.shape
# Out:
# (15214, 33)

# %%
def extract_date(data):
    date, _ = data.split(' ')
    return date

# %%
data['date'] = data['timestamp'].apply(lambda x : extract_date(x))
data['date'] =  pd.to_datetime(data['date'])
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %%
data.T.head(20)
# Out:
#                                          0                    1      \
# Case-Id                                    232                  425
# Case-concept:name                           XH                   JP
# Event-Id                                  3078                 6195
# sorting                                     20                    5
# timestamp                  2014-03-27 09:00:00  2014-05-03 18:26:00
# Event-Name                                 CRP                  CRP
# org:group                                    B                    B
# age                                         90                   35
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          2                    3      \
# Case-Id                                    728                  978
# Case-concept:name                          ABA                  QKA
# Event-Id                                 10599                14200
# sorting                                      6                    4
# timestamp                  2014-10-12 10:10:00  2013-11-16 08:21:00
# Event-Name                          Leucocytes           Leucocytes
# org:group                                    B                    B
# age                                         75                   85
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          4                    5      \
# Case-Id                                     11                   40
# Case-concept:name                            K                  NaN
# Event-Id                                   132                  455
# sorting                                      6                   14
# timestamp                  2014-02-23 21:15:00  2014-11-13 06:00:00
# Event-Name                          Leucocytes           Leucocytes
# org:group                                    B                    B
# age                                         50                   90
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          6                    7      \
# Case-Id                                     46                   51
# Case-concept:name                           TA                   YA
# Event-Id                                   521                  562
# sorting                                      8                    4
# timestamp                  2014-08-10 06:00:00  2014-07-10 10:54:00
# Event-Name                          Leucocytes           Leucocytes
# org:group                                    B                    B
# age                                         80                   90
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          8                    9      \
# Case-Id                                     67                   68
# Case-concept:name                           OB                   PB
# Event-Id                                   746                  760
# sorting                                     14                   12
# timestamp                  2014-12-12 06:00:00  2015-01-19 10:00:00
# Event-Name                          Leucocytes           Leucocytes
# org:group                                    B                    B
# age                                         80                   80
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                   ...                         15204  \
# Case-Id                           ...                          1047
# Case-concept:name                 ...                           INA
# Event-Id                          ...                         15193
# sorting                           ...                             3
# timestamp                         ...           2014-11-03 09:45:51
# Event-Name                        ...              ER Sepsis Triage
# org:group                         ...                             A
# age                               ...                            25
# crp                               ...                           NaN
# diagnose                          ...                           NaN
# diagnosticartastrup               ...                           NaN
# diagnosticblood                   ...                           NaN
# diagnosticecg                     ...                           NaN
# diagnosticic                      ...                           NaN
# diagnosticlacticacid              ...                           NaN
# diagnosticliquor                  ...                           NaN
# diagnosticother                   ...                           NaN
# diagnosticsputum                  ...                           NaN
# diagnosticurinaryculture          ...                           NaN
# diagnosticurinarysediment         ...                           NaN
#
#                                          15205                15206  \
# Case-Id                                   1048                 1048
# Case-concept:name                          JNA                  JNA
# Event-Id                                 15194                15195
# sorting                                      1                    2
# timestamp                  2014-11-12 16:40:19  2014-11-12 16:47:25
# Event-Name                     ER Registration            ER Triage
# org:group                                    A                    C
# age                                         40                   40
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                          0                  NaN
# diagnosticblood                              0                  NaN
# diagnosticecg                                0                  NaN
# diagnosticic                                 0                  NaN
# diagnosticlacticacid                         0                  NaN
# diagnosticliquor                             0                  NaN
# diagnosticother                              0                  NaN
# diagnosticsputum                             0                  NaN
# diagnosticurinaryculture                     0                  NaN
# diagnosticurinarysediment                    0                  NaN
#
#                                          15207                15208  \
# Case-Id                                   1048                 1049
# Case-concept:name                          JNA                  KNA
# Event-Id                                 15196                15197
# sorting                                      3                    1
# timestamp                  2014-11-12 16:47:39  2014-12-11 22:28:38
# Event-Name                    ER Sepsis Triage      ER Registration
# org:group                                    A                    A
# age                                         40                   35
# crp                                        NaN                  NaN
# diagnose                                   NaN                   QE
# diagnosticartastrup                        NaN                    1
# diagnosticblood                            NaN                    1
# diagnosticecg                              NaN                    1
# diagnosticic                               NaN                    1
# diagnosticlacticacid                       NaN                    1
# diagnosticliquor                           NaN                    0
# diagnosticother                            NaN                    0
# diagnosticsputum                           NaN                    0
# diagnosticurinaryculture                   NaN                    0
# diagnosticurinarysediment                  NaN                    1
#
#                                          15209                15210  \
# Case-Id                                   1049                 1049
# Case-concept:name                          KNA                  KNA
# Event-Id                                 15198                15199
# sorting                                      2                    3
# timestamp                  2014-12-11 22:52:48  2014-12-11 22:53:16
# Event-Name                           ER Triage     ER Sepsis Triage
# org:group                                    C                    A
# age                                         35                   35
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          15211                15212  \
# Case-Id                                   1049                 1049
# Case-concept:name                          KNA                  KNA
# Event-Id                                 15203                15204
# sorting                                      7                    8
# timestamp                  2014-12-12 04:03:38  2014-12-12 04:03:43
# Event-Name                           IV Liquid       IV Antibiotics
# org:group                                    A                    A
# age                                         35                   35
# crp                                        NaN                  NaN
# diagnose                                   NaN                  NaN
# diagnosticartastrup                        NaN                  NaN
# diagnosticblood                            NaN                  NaN
# diagnosticecg                              NaN                  NaN
# diagnosticic                               NaN                  NaN
# diagnosticlacticacid                       NaN                  NaN
# diagnosticliquor                           NaN                  NaN
# diagnosticother                            NaN                  NaN
# diagnosticsputum                           NaN                  NaN
# diagnosticurinaryculture                   NaN                  NaN
# diagnosticurinarysediment                  NaN                  NaN
#
#                                          15213
# Case-Id                                   1049
# Case-concept:name                          KNA
# Event-Id                                 15205
# sorting                                      9
# timestamp                  2014-12-12 04:06:38
# Event-Name                        Admission NC
# org:group                                    Q
# age                                         35
# crp                                        NaN
# diagnose                                   NaN
# diagnosticartastrup                        NaN
# diagnosticblood                            NaN
# diagnosticecg                              NaN
# diagnosticic                               NaN
# diagnosticlacticacid                       NaN
# diagnosticliquor                           NaN
# diagnosticother                            NaN
# diagnosticsputum                           NaN
# diagnosticurinaryculture                   NaN
# diagnosticurinarysediment                  NaN
#
# [20 rows x 15214 columns]

# %%
columns_select = ['date', 'Case-Id', 'sorting']
df = data[columns_select].sort_values('date')
df.head()
# Out:
#            date  Case-Id
# 9958 2013-11-07      283
# 9957 2013-11-07      283
# 813  2013-11-07      283
# 9959 2013-11-07      283
# 9960 2013-11-07      283

# %%
df  = df.groupby('date').agg(['count'])
df = df.reset_index()
df.head()
# Out:
#         date Case-Id
#                count
# 0 2013-11-07       9
# 1 2013-11-08       1
# 2 2013-11-09      15
# 3 2013-11-11      11
# 4 2013-11-12      11

# %%
df.columns = ['ds', 'y']
start_date = '2014-01-01'
end_date =  '2014-03-01'
mask = (df['ds'] > start_date) & (df['ds'] <= end_date)
df = df.loc[mask]

# %%
df.head()
# Out:
#            ds   y
# 54 2014-01-02  30
# 55 2014-01-03  10
# 56 2014-01-04  45
# 57 2014-01-05  26
# 58 2014-01-06  44

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
m = Prophet()
m.fit(df)

# %%
future = m.make_future_dataframe(periods=7)
#future.tail()

# %%
forecast = m.predict(future)
#forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
m.plot(forecast);

# %%
m.plot_components(forecast);

# %%
from fbprophet.diagnostics import cross_validation
df_cv = cross_validation(m, horizon = '7 days')

# %%
df_cv.head(7)
# Out:
#           ds       yhat  yhat_lower  yhat_upper   y     cutoff
# 0 2014-01-26  15.797067    4.366662   28.269794  18 2014-01-25
# 1 2014-01-27  10.252043   -1.681790   22.333131  22 2014-01-25
# 2 2014-01-28  13.797991    0.822461   25.903655  10 2014-01-25
# 3 2014-01-29  13.639317    2.339972   26.244908  26 2014-01-25
# 4 2014-01-30   9.454447   -3.457159   20.710360  25 2014-01-25
# 5 2014-01-31   1.178743  -11.439180   14.148817  13 2014-01-25
# 6 2014-02-01   7.175174   -5.206409   20.685159  25 2014-01-25
